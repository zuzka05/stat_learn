# %% [markdown]
# <a href="https://colab.research.google.com/github/zuzka05/stat_learn/blob/main/Quant_Trading_Accelerator_Video_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Quant Trading Accelerator 🚀

# %% [markdown]
# Learn from 0, extremely fast => Learn by Building 🚀

# %% [markdown]
# **Prerequisites**
#
# * Intellectual Curiosity

# %% [markdown]
# **What is Quant Trading?**
#
# Input -> **Model** -> Prediction -> **Strategy** -> Orders -> **Execution**

# %% [markdown]
# ## Course Overview

# %% [markdown]
# **Objectives**:
#
# 1. Develop Quant Research Skills
# 2. Develop and Backtest Quant Models
# 3. Develop and Backtest Quant Strategies
# 4. Implement and Automate Strategies

# %% [markdown]
# **What are we going to be building?**
#
# 1. Data Analysis Library
# 2. Research Library
# 3. Build and backtest a basic Machine Learning Model
# 4. Build and backtest a basic Quant Trading Strategy

# %% [markdown]
# **Key Skills**:
#
# 1. Programming
# 2. Mathematics
# 3. Econometrics
# 4. Machine Learning

# %% [markdown]
# **Course Logistics:**
#
# * **Google Colab**: No installation required
# * **Videos**: bite-sized => ~20 mins each
# * **Learning**: increment, just-in-time learning
# * **Don't skip**: each video builds upon the other
# * **Exercises**: please do them! Not building = not learning
# * **Please comment**: my only feedback signal

# %% [markdown]
# # Part 1: Variables

# %%
1 + 2 + 3
# Out:
# 6

# %%
price = 10.0

# %%
price
# Out:
# 10.0

# %%
price = price + 0.5

# %%
price
# Out:
# 10.5

# %%
old_price = price - 0.5

# %%
old_price
# Out:
# 10.0

# %%
old_price = 10.5 - 0.5

# %%
old_price
# Out:
# 10.0

# %%
price = 10.0
new_price = price
price = 11.0

# %%
new_price
# Out:
# 10.0

# %%
price
# Out:
# 11.0

# %% [markdown]
# ### Numbers

# %%
type(price)
# Out:
# float

# %%
no_trades = 100

# %%
no_trades
# Out:
# 100

# %%
type(no_trades)
# Out:
# int

# %%
no_trades = float(no_trades)

# %%
type(no_trades)
# Out:
# float

# %%
no_trades
# Out:
# 100.0

# %%
int(100.12)
# Out:
# 100

# %%
float(100)
# Out:
# 100.0

# %%
float("262.82")
# Out:
# 262.82

# %% [markdown]
# ### Arithmetic

# %%
3 + 3 * 3
# Out:
# 12

# %%
3 + 9
# Out:
# 12

# %%
(3 + 3) * 3
# Out:
# 18

# %%
6 * 3
# Out:
# 18

# %%
price * 1.05
# Out:
# 11.55

# %%
price * (1 - 0.1)
# Out:
# 9.9

# %% [markdown]
# ### Strings

# %%
symbol = 'GOOG'

# %%
symbol
# Out:
# 'GOOG'

# %%
type(symbol)
# Out:
# str

# %%
#String concatenation
col = symbol + "_price"

# %%
col
# Out:
# 'GOOG_price'

# %%
col = "price_" + symbol

# %%
col
# Out:
# 'price_GOOG'

# %%
col.replace("_","-")
# Out:
# 'price-GOOG'

# %%
col
# Out:
# 'price_GOOG'

# %%
col = col.replace("_", "-")

# %%
#If we want to save it, we need to update a variable
#Operations on the string are often immutable - the data doesn't change
#It creates a new memory allocation
col
# Out:
# 'price-GOOG'

# %%
#When we split the string, it creates an array
col.split('-')
# Out:
# ['price', 'GOOG']

# %%
tokens = col.split('-')

# %%
#we save an array
tokens
# Out:
# ['price', 'GOOG']

# %%
#access individual element of the array
tokens[0]
# Out:
# 'price'

# %%
tokens[1]
# Out:
# 'GOOG'

# %%
#an algo is finding what the index is
i = col.find('-')

# %%
i
# Out:
# 5

# %%
#the first token
col[0:i]
# Out:
# 'price'

# %%
#the second token
col[i+1:]
# Out:
# 'GOOG'

# %%
price
# Out:
# 11.0

# %%
# formatting strings
# symbol + " price is " + price

# %%
#you can only concatenate string
#need to move float to string
symbol + " price is " + str(price)
# Out:
# 'GOOG price is 11.0'

# %%
#formatter string
f"{symbol} price is {price}"
# Out:
# 'GOOG price is 11.0'

# %% [markdown]
# ## Exercise 1: Calculate Price Delta

# %%
price_today = 100.0
price_yesterday = 90.0

price_delta = 0.0

# %%
price_delta = price_today - price_yesterday

# %%
price_delta
# Out:
# 10.0

# %%
#Boolean: True or False
price_delta == 10
# Out:
# True

# %% [markdown]
# ## Exercise 2: Calculate Total Profit & Loss (PnL)

# %%
trade1_pnl = 1.2
trade2_pnl = -2.0
trade3_pnl = 3.0
trade4_pnl = 8.5

total_pnl = 0.0

# %%
total_pnl = trade1_pnl + trade2_pnl + trade3_pnl + trade4_pnl

# %%
total_pnl
# Out:
# 10.7

# %%
total_pnl == 10.7
# Out:
# True

# %% [markdown]
# ## Exercise 3: Parse Data

# %%
#do string processing
s = 'AAPL:262.82'

symbol = ''
price = 0.0

# %%
s = s.split(':')

# %%
s
# Out:
# ['AAPL', '262.82']

# %%
symbol = s[0]

# %%
symbol
# Out:
# 'AAPL'

# %%
price = s[1]

# %%
price = float(price)

# %%
price
# Out:
# 262.82

# %%
symbol == 'AAPL'
# Out:
# True

# %%
price == 262.82
# Out:
# False
